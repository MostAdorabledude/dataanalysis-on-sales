# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
matplotlib inline

# %%
sales_data = pd.read_csv(r'C:\Users\Paul Fadayini\Desktop\titucodes\dataresources\Superstore_data.csv', encoding = 'latin1')

# %%
sales_data['calculated_price']=sales_data['Sales']/ sales_data['Quantity']

# %%
sales_data['calculated_price'].head()
# Out:
# 0    130.9800
# 1    243.9800
# 2      7.3100
# 3    191.5155
# 4     11.1840
# Name: calculated_price, dtype: float64

# %%
sales_data['Discounted_price']= sales_data['calculated_price']-(sales_data['Discount'] * sales_data['calculated_price'])
sales_data['Discounted_price'].head()
# Out:
# 2697    1886.5400
# 6826    3499.9900
# 8153    3499.9900
# 2623    2239.9936
# 4190    3499.9900
# Name: Discounted_price, dtype: float64

# %%
sales_data.head()
# Out:
#       Row ID        Order ID  Order Date  Ship Date       Ship Mode  \
# 2697    2698  CA-2011-145317   3/18/2011 2011-03-23  Standard Class
# 6826    6827  CA-2013-118689   10/3/2013 2013-10-10  Standard Class
# 8153    8154  CA-2014-140151   3/24/2014 2014-03-26     First Class
# 2623    2624  CA-2014-127180  10/23/2014 2014-10-25     First Class
# 4190    4191  CA-2014-166709  11/18/2014 2014-11-23  Standard Class
#
#      Customer ID Customer Name      Segment        Country           City  \
# 2697    SM-20320   Sean Miller  Home Office  United States   Jacksonville
# 6826    TC-20980  Tamara Chand    Corporate  United States      Lafayette
# 8153    RB-19360  Raymond Buch     Consumer  United States        Seattle
# 2623    TA-21385  Tom Ashbrook  Home Office  United States  New York City
# 4190    HL-15040  Hunter Lopez     Consumer  United States         Newark
#
#       ... Sub-Category                                       Product Name  \
# ...

# %%
sales_data['Cost_price']=sales_data['calculated_price']-sales_data['Profit']
sales_data['Cost_price'].head()
# Out:
# 0     89.0664
# 1     24.3980
# 2      0.4386
# 3    574.5465
# 4      8.6676
# Name: Cost_price, dtype: float64

# %%
sales_data.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2013-152156   11/9/2013  11/12/2013    Second Class    CG-12520
# 1       2  CA-2013-152156   11/9/2013  11/12/2013    Second Class    CG-12520
# 2       3  CA-2013-138688   6/13/2013   6/17/2013    Second Class    DV-13045
# 3       4  US-2012-108966  10/11/2012  10/18/2012  Standard Class    SO-20335
# 4       5  US-2012-108966  10/11/2012  10/18/2012  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#           Category  Sub-Category  \
# 0        Furniture     Bookcases
# ...

# %% [markdown]
# # TO FIND SALES BY CATEGORY OF PRODUCTS

# %%
sales_by_cat=sales_data.groupby(sales_data['Category']).Sales.sum()
sales_by_cat.head()
# Out:
# Category
# Furniture          741999.7953
# Office Supplies    719047.0320
# Technology         836154.0330
# Name: Sales, dtype: float64

# %% [markdown]
# # TO FIND THE PROFIT OF EACH CATEGORY OF PRODUCTS MADE

# %%
profit_by_cat=sales_data.groupby(['Category']).Profit.sum()
print(profit_by_cat)
# Out:
# Category
# Furniture           18451.2728
# Office Supplies    122490.8008
# Technology         145454.9481
# Name: Profit, dtype: float64

# %% [markdown]
# # sales by year

# %%
#this code is to convert the data type in the 'ship date' from string to date time 
sales_data['Ship Date']=pd.to_datetime(sales_data['Ship Date'])
#after adusting data type, next line of code creates a column consisting of ust the year of shipment
sales_data['Year']=sales_data['Ship Date'].dt.year
sales_data.head()
# Out:
#       Row ID        Order ID  Order Date  Ship Date       Ship Mode  \
# 2697    2698  CA-2011-145317   3/18/2011 2011-03-23  Standard Class
# 6826    6827  CA-2013-118689   10/3/2013 2013-10-10  Standard Class
# 8153    8154  CA-2014-140151   3/24/2014 2014-03-26     First Class
# 2623    2624  CA-2014-127180  10/23/2014 2014-10-25     First Class
# 4190    4191  CA-2014-166709  11/18/2014 2014-11-23  Standard Class
#
#      Customer ID Customer Name      Segment        Country           City  \
# 2697    SM-20320   Sean Miller  Home Office  United States   Jacksonville
# 6826    TC-20980  Tamara Chand    Corporate  United States      Lafayette
# 8153    RB-19360  Raymond Buch     Consumer  United States        Seattle
# 2623    TA-21385  Tom Ashbrook  Home Office  United States  New York City
# 4190    HL-15040  Hunter Lopez     Consumer  United States         Newark
#
#       ...    Category  Sub-Category  \
# 2697  ...  Technology      Machines
# ...

# %%
sales_by_year=sales_data.groupby(['Year'])['Sales']. sum()
print(sales_by_year)
# Out:
# Year
# 2011    470383.1931
# 2012    479442.5020
# 2013    606285.4570
# 2014    733727.5494
# 2015      7362.1588
# Name: Sales, dtype: float64

# %% [markdown]
# # Top ten selling product

# %%
#first group data by product name and total sales
top_ten=sales_data.groupby(['Product Name']).Sales.sum()
#then sort in ascending order to get the highest products sold
top_ten.sort_values(ascending=False).head(10)
# Out:
# Product Name
# Canon imageCLASS 2200 Advanced Copier                                          61599.824
# Fellowes PB500 Electric Punch Plastic Comb Binding Machine with Manual Bind    27453.384
# Cisco TelePresence System EX90 Videoconferencing Unit                          22638.480
# HON 5400 Series Task Chairs for Big and Tall                                   21870.576
# GBC DocuBind TL300 Electric Binding System                                     19823.479
# GBC Ibimaster 500 Manual ProClick Binding System                               19024.500
# Hewlett Packard LaserJet 3310 Copier                                           18839.686
# HP Designjet T520 Inkjet Large Format Printer - 24" Color                      18374.895
# GBC DocuBind P400 Electric Binding System                                      17965.068
# High Speed Automatic Electric Letter Opener                                    17030.312
# Name: Sales, dtype: float64

# %% [markdown]
# # sales_by_shipmode

# %%
sales_by_shipmode=sales_data.groupby(['Ship Mode']).Sales.sum()
print(sales_by_shipmode)
# Out:
# Ship Mode
# First Class       3.514284e+05
# Same Day          1.283631e+05
# Second Class      4.591936e+05
# Standard Class    1.358216e+06
# Name: Sales, dtype: float64
